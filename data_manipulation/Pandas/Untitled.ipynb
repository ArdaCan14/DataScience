# %%
import numpy as np
import pandas as pd

# %%
nf = pd.read_csv("netflix_titles.csv")
nf
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
nf[nf["country"].isin(["United States","United Kingdom"])]
# Out:
#      show_id     type                          title         director  \
# 0         s1    Movie           Dick Johnson Is Dead  Kirsten Johnson
# 8         s9  TV Show  The Great British Baking Show  Andy Devonshire
# 9        s10    Movie                   The Starling   Theodore Melfi
# 15       s16  TV Show              Dear White People              NaN
# 27       s28    Movie                      Grown Ups     Dennis Dugan
# ...      ...      ...                            ...              ...
# 8791   s8792    Movie                    Young Adult    Jason Reitman
# 8793   s8794    Movie           Yours, Mine and Ours     Raja Gosnell
# 8802   s8803    Movie                         Zodiac    David Fincher
# 8804   s8805    Movie                     Zombieland  Ruben Fleischer
# 8805   s8806    Movie                           Zoom     Peter Hewitt
#
#                                                    cast         country  \
# ...

# %%
nf[nf["title"] == "Breaking Bad"]
# Out:
#      show_id     type         title director  \
# 5940   s5941  TV Show  Breaking Bad      NaN
#
#                                                    cast        country  \
# 5940  Bryan Cranston, Aaron Paul, Anna Gunn, Dean No...  United States
#
#           date_added  release_year rating   duration  \
# 5940  August 2, 2013          2013  TV-MA  5 Seasons
#
#                                     listed_in  \
# 5940  Crime TV Shows, TV Dramas, TV Thrillers
#
#                                             description
# 5940  A high school chemistry teacher dying of cance...

# %%
nf[nf["title"] == "The Vampire Diaries"]
# Out:
#      show_id     type                title director  \
# 5287   s5288  TV Show  The Vampire Diaries      NaN
#
#                                                    cast        country  \
# 5287  Nina Dobrev, Paul Wesley, Ian Somerhalder, Ste...  United States
#
#              date_added  release_year rating   duration  \
# 5287  September 4, 2017          2016  TV-14  8 Seasons
#
#                                          listed_in  \
# 5287  TV Dramas, TV Mysteries, TV Sci-Fi & Fantasy
#
#                                             description
# 5287  Trapped in adolescent bodies, feuding vampire ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
planet = sns.load_dataset("planets")
planet.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df = planet.copy()
df
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
df["year"].max()
# Out:
# 2014

# %%
df["year"].min()
# Out:
# 1989

# %%
df["year"].mean()
# Out:
# 2009.0705314009663

# %%
df.groupby("method")[["distance"]].mean()
# Out:
#                                   distance
# method
# Astrometry                       17.875000
# Eclipse Timing Variations       315.360000
# Imaging                          67.715937
# Microlensing                   4144.000000
# Orbital Brightness Modulation  1180.000000
# Pulsar Timing                  1200.000000
# Pulsation Timing Variations            NaN
# Radial Velocity                  51.600208
# Transit                         599.298080
# Transit Timing Variations      1104.333333

# %%
df.groupby("mass")[["orbital_period"]].mean()
# Out:
#           orbital_period
# mass
# 0.00360          3.23570
# 0.00600          3.14942
# 0.00755         40.11400
# 0.00800         50.63300
# 0.00850         18.31500
# ...                  ...
# 19.40000       326.03000
# 19.80000       677.80000
# 20.60000       305.50000
# 21.42000       379.63000
# 25.00000      2371.00000
#
# [381 rows x 1 columns]

# %%
df[df["method"].isin(["Microlensing","Astrometry"])]
# Out:
#            method  number  orbital_period  mass  distance  year
# 113    Astrometry       1          246.36   NaN     20.77  2013
# 537    Astrometry       1         1016.00   NaN     14.98  2010
# 902  Microlensing       1             NaN   NaN       NaN  2008
# 903  Microlensing       1             NaN   NaN       NaN  2008
# 904  Microlensing       1             NaN   NaN       NaN  2009
# 905  Microlensing       1             NaN   NaN   3600.00  2013
# 906  Microlensing       1         2780.00   NaN       NaN  2011
# 907  Microlensing       1             NaN   NaN       NaN  2010
# 908  Microlensing       1         1970.00   NaN       NaN  2010
# 909  Microlensing       1             NaN   NaN   2300.00  2012
# 910  Microlensing       1             NaN   NaN   2800.00  2012
# 911  Microlensing       1             NaN   NaN   7720.00  2012
# 912  Microlensing       1             NaN   NaN   7560.00  2013
# 917  Microlensing       1             NaN   NaN       NaN  2004
# ...

# %%
df["mass"].max()
# Out:
# 25.0

# %%
df[df["mass"] == 25.0]
# Out:
#               method  number  orbital_period  mass  distance  year
# 321  Radial Velocity       1          2371.0  25.0     37.05  2008

# %%
df["distance"].max()
# Out:
# 8500.0

# %%
df[df["distance"] == 8500.0]
# Out:
#       method  number  orbital_period  mass  distance  year
# 951  Transit       1           4.200   NaN    8500.0  2006
# 952  Transit       1           1.796   NaN    8500.0  2006

# %%
year = pd.cut(df["year"],[1989,2009,2014])

# %%
df.pivot_table("distance",["method",year])
# Out:
#                                                distance
# method                        year
# Astrometry                    (2009, 2014]    17.875000
# Eclipse Timing Variations     (1989, 2009]   130.720000
#                               (2009, 2014]   500.000000
# Imaging                       (1989, 2009]    59.801875
#                               (2009, 2014]    75.630000
# Microlensing                  (2009, 2014]  4144.000000
# Orbital Brightness Modulation (2009, 2014]  1180.000000
# Pulsar Timing                 (2009, 2014]  1200.000000
# Radial Velocity               (1989, 2009]    48.403860
#                               (2009, 2014]    56.913350
# Transit                       (1989, 2009]   723.257045
#                               (2009, 2014]   568.997000
# Transit Timing Variations     (2009, 2014]  1104.333333

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
planet = sns.load_dataset("planets")
planet.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df = planet.copy()
df.head(10)
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009
# 5  Radial Velocity       1         185.840   4.80     76.39  2008
# 6  Radial Velocity       1        1773.400   4.64     18.15  2002
# 7  Radial Velocity       1         798.500    NaN     21.41  1996
# 8  Radial Velocity       1         993.300  10.30     73.10  2008
# 9  Radial Velocity       2         452.800   1.99     74.79  2010

# %%
df.groupby("method")[["distance"]].mean()
# Out:
#                                   distance
# method
# Astrometry                       17.875000
# Eclipse Timing Variations       315.360000
# Imaging                          67.715937
# Microlensing                   4144.000000
# Orbital Brightness Modulation  1180.000000
# Pulsar Timing                  1200.000000
# Pulsation Timing Variations            NaN
# Radial Velocity                  51.600208
# Transit                         599.298080
# Transit Timing Variations      1104.333333

# %%
df["distance"].max()
# Out:
# 8500.0

# %%
df[df["distance"] == 8500.0]
# Out:
#       method  number  orbital_period  mass  distance  year
# 951  Transit       1           4.200   NaN    8500.0  2006
# 952  Transit       1           1.796   NaN    8500.0  2006

# %%
df[df["method"] == "Microlensing"]
# Out:
#            method  number  orbital_period  mass  distance  year
# 902  Microlensing       1             NaN   NaN       NaN  2008
# 903  Microlensing       1             NaN   NaN       NaN  2008
# 904  Microlensing       1             NaN   NaN       NaN  2009
# 905  Microlensing       1             NaN   NaN    3600.0  2013
# 906  Microlensing       1          2780.0   NaN       NaN  2011
# 907  Microlensing       1             NaN   NaN       NaN  2010
# 908  Microlensing       1          1970.0   NaN       NaN  2010
# 909  Microlensing       1             NaN   NaN    2300.0  2012
# 910  Microlensing       1             NaN   NaN    2800.0  2012
# 911  Microlensing       1             NaN   NaN    7720.0  2012
# 912  Microlensing       1             NaN   NaN    7560.0  2013
# 917  Microlensing       1             NaN   NaN       NaN  2004
# 918  Microlensing       1          3600.0   NaN       NaN  2005
# 919  Microlensing       1          3300.0   NaN       NaN  2006
# ...

# %%
df["mass"].max()
# Out:
# 25.0

# %%
df[df["mass"] == 25.0]
# Out:
#               method  number  orbital_period  mass  distance  year
# 321  Radial Velocity       1          2371.0  25.0     37.05  2008

# %%
year = pd.cut(df["year"],[1989,2009,2015])

# %%
df.pivot_table("distance",["method",year])
# Out:
#                                                distance
# method                        year
# Astrometry                    (2009, 2015]    17.875000
# Eclipse Timing Variations     (1989, 2009]   130.720000
#                               (2009, 2015]   500.000000
# Imaging                       (1989, 2009]    59.801875
#                               (2009, 2015]    75.630000
# Microlensing                  (2009, 2015]  4144.000000
# Orbital Brightness Modulation (2009, 2015]  1180.000000
# Pulsar Timing                 (2009, 2015]  1200.000000
# Radial Velocity               (1989, 2009]    48.403860
#                               (2009, 2015]    56.913350
# Transit                       (1989, 2009]   723.257045
#                               (2009, 2015]   568.997000
# Transit Timing Variations     (2009, 2015]  1104.333333

# %%
df[df["method"].isin(["Astrometry","Microlensing"])]
# Out:
#            method  number  orbital_period  mass  distance  year
# 113    Astrometry       1          246.36   NaN     20.77  2013
# 537    Astrometry       1         1016.00   NaN     14.98  2010
# 902  Microlensing       1             NaN   NaN       NaN  2008
# 903  Microlensing       1             NaN   NaN       NaN  2008
# 904  Microlensing       1             NaN   NaN       NaN  2009
# 905  Microlensing       1             NaN   NaN   3600.00  2013
# 906  Microlensing       1         2780.00   NaN       NaN  2011
# 907  Microlensing       1             NaN   NaN       NaN  2010
# 908  Microlensing       1         1970.00   NaN       NaN  2010
# 909  Microlensing       1             NaN   NaN   2300.00  2012
# 910  Microlensing       1             NaN   NaN   2800.00  2012
# 911  Microlensing       1             NaN   NaN   7720.00  2012
# 912  Microlensing       1             NaN   NaN   7560.00  2013
# 917  Microlensing       1             NaN   NaN       NaN  2004
# ...
