# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("DiamondData.csv")
df.head(50)
# Out:
#     carat        cut color clarity  depth  table    price     x     y     z
# 0    1.50       Fair     G     SI1   64.5   57.0  10352.0  7.15  7.09  4.59
# 1    0.70      Ideal     E     VS2   61.4   57.0   2274.0  5.72  5.78  3.53
# 2    1.22    Premium     G     VS1   61.3   58.0   8779.0  6.91  6.89  4.23
# 3    0.51    Premium     E     VS2   62.5   60.0   1590.0  5.08  5.10  3.18
# 4    2.02  Very Good     J     SI2   59.2   60.0  11757.0  8.27  8.39  4.91
# 5    0.70  Very Good     E     SI1   63.2   61.0   2164.0  5.61  5.49  3.51
# 6    0.46      Ideal     G    VVS1   60.7   57.0   1453.0  4.98  5.03  3.04
# 7    0.55    Premium     F     SI2   60.6   58.0   1175.0  5.28  5.31  3.21
# 8    0.51      Ideal     G    VVS2   61.6   56.0   1750.0  5.12  5.14  3.16
# 9    0.50      Ideal     H     VS2   62.3   55.0   1921.0  5.09  5.12  3.18
# 10   1.51    Premium     J     VS1   62.1   58.0   8524.0  7.40  7.36  4.58
# ...

# %%
df.groupby("cut")[["price","carat","depth"]].mean()
# Out:
#                  price     carat      depth
# cut
# Fair       4354.719702  1.262045  64.057065
# Good       3947.706661  0.965300  62.360744
# Ideal      3459.286371  0.823890  61.709723
# Premium    4591.519724  0.990755  61.263538
# Very Geod  4066.674731  0.889305  61.814376
# Very Good  3963.478022  0.887739  61.818946

# %%
df.groupby(["cut","color"])[["price","depth"]].aggregate("mean")
# Out:
#                        price      depth
# cut       color
# Fair      D      4284.048276  63.872222
#           E      3708.645933  63.361538
#           F      3838.879433  63.491367
#           G      4213.326316  64.423592
#           H      5125.953571  64.660714
#           I      4715.521472  64.191875
#           J      4852.814159  64.362162
# Good      D      3415.981848  62.360826
#           E      3475.044674  62.193135
#           F      3534.673077  62.185851
#           G      4112.836025  62.519048
#           H      4276.027565  62.498145
#           I      5158.039749  62.465828
#           J      4479.557491  62.455634
# Ideal     D      2602.221707  61.684806
#           E      2604.844837  61.686320
#           F      3383.378049  61.678811
#           G      3715.558935  61.700178
#           H      3887.814570  61.726627
#           I      4457.471904  61.786660
#           J      4931.567665  61.833815
# Premium   D      3647.365722  61.167096
# ...

# %%
df.pivot_table("carat","cut","color","price")
# Out:
# price            326.0    335.0    336.0    337.0    338.0    339.0    \
# cut       color
# Fair      D          NaN      NaN      NaN      NaN      NaN      NaN
#           E          NaN      NaN      NaN     0.22      NaN      NaN
#           F          NaN      NaN      NaN      NaN      NaN      NaN
#           G          NaN      NaN      NaN      NaN      NaN      NaN
#           H          NaN      NaN      NaN      NaN      NaN      NaN
#           I          NaN      NaN      NaN      NaN      NaN      NaN
#           J          NaN      NaN      NaN      NaN      NaN      NaN
# Good      D          NaN      NaN      NaN      NaN      NaN      NaN
#           E          NaN      NaN      NaN      NaN      NaN      NaN
#           F          NaN      NaN      NaN      NaN      NaN      NaN
#           G          NaN      NaN      NaN      NaN      NaN      NaN
#           H          NaN      NaN      NaN      NaN      NaN      NaN
# ...

# %%
import numpy as np
import pandas as pd
dia = pd.read_csv("DiamondData.csv")
dia.head(20)
# Out:
#     carat        cut color clarity  depth  table    price     x     y     z
# 0    1.50       Fair     G     SI1   64.5   57.0  10352.0  7.15  7.09  4.59
# 1    0.70      Ideal     E     VS2   61.4   57.0   2274.0  5.72  5.78  3.53
# 2    1.22    Premium     G     VS1   61.3   58.0   8779.0  6.91  6.89  4.23
# 3    0.51    Premium     E     VS2   62.5   60.0   1590.0  5.08  5.10  3.18
# 4    2.02  Very Good     J     SI2   59.2   60.0  11757.0  8.27  8.39  4.91
# 5    0.70  Very Good     E     SI1   63.2   61.0   2164.0  5.61  5.49  3.51
# 6    0.46      Ideal     G    VVS1   60.7   57.0   1453.0  4.98  5.03  3.04
# 7    0.55    Premium     F     SI2   60.6   58.0   1175.0  5.28  5.31  3.21
# 8    0.51      Ideal     G    VVS2   61.6   56.0   1750.0  5.12  5.14  3.16
# 9    0.50      Ideal     H     VS2   62.3   55.0   1921.0  5.09  5.12  3.18
# 10   1.51    Premium     J     VS1   62.1   58.0   8524.0  7.40  7.36  4.58
# ...

# %%
dia.groupby("cut")[["price","carat"]].mean()
# Out:
#                  price     carat
# cut
# Fair       4354.719702  1.262045
# Good       3947.706661  0.965300
# Ideal      3459.286371  0.823890
# Premium    4591.519724  0.990755
# Very Geod  4066.674731  0.889305
# Very Good  3963.478022  0.887739

# %%
dia[dia["carat"] > 0.9].head(10)
# Out:
#     carat        cut color clarity  depth  table    price     x     y     z
# 0    1.50       Fair     G     SI1   64.5   57.0  10352.0  7.15  7.09  4.59
# 2    1.22    Premium     G     VS1   61.3   58.0   8779.0  6.91  6.89  4.23
# 4    2.02  Very Good     J     SI2   59.2   60.0  11757.0  8.27  8.39  4.91
# 10   1.51    Premium     J     VS1   62.1   58.0   8524.0  7.40  7.36  4.58
# 12   1.05    Premium     D     SI1   61.6   61.0   5351.0  6.55  6.50  4.02
# 13   1.18      Ideal     H     SI2   62.2   56.0   5657.0  6.74  6.76  4.20
# 14   1.32      Ideal     E     SI2   62.7   56.0   7037.0  7.03  6.97  4.39
# 16   1.32      Ideal     G     VS1   61.6   57.0  12094.0  6.97  7.05  4.32
# 17   1.80  Very Geod     J     SI1   61.4   55.0  10107.0  7.86  7.80  4.81
# 21   1.01    Premium     D    VVS2   62.4   60.0  10407.0  6.36  6.31  3.95

# %%
dia2 = dia.copy()

# %%
dia2[dia2["cut"].isin(["Premium","Fair"])].head(30)
# Out:
#     carat      cut color clarity  depth  table    price     x     y     z
# 0    1.50     Fair     G     SI1   64.5   57.0  10352.0  7.15  7.09  4.59
# 2    1.22  Premium     G     VS1   61.3   58.0   8779.0  6.91  6.89  4.23
# 3    0.51  Premium     E     VS2   62.5   60.0   1590.0  5.08  5.10  3.18
# 7    0.55  Premium     F     SI2   60.6   58.0   1175.0  5.28  5.31  3.21
# 10   1.51  Premium     J     VS1   62.1   58.0   8524.0  7.40  7.36  4.58
# 12   1.05  Premium     D     SI1   61.6   61.0   5351.0  6.55  6.50  4.02
# 19   0.73  Premium     H     VS1   61.7   58.0   2468.0  5.75  5.72  3.54
# 21   1.01  Premium     D    VVS2   62.4   60.0  10407.0  6.36  6.31  3.95
# 22   1.00  Premium     F     VS2   62.7   58.0   6608.0  6.40  6.33  3.99
# 25   0.90     Fair     G     SI2   55.9   62.0   3104.0  6.35  6.42  3.57
# 30   1.06  Premium     G    VVS2   59.6   58.0   8003.0  6.61  6.65  3.95
# 33   0.43  Premium     E     SI2   61.8   60.0    882.0  4.85  4.83  2.99
# ...

# %%
dia.groupby("cut").aggregate("mean")
# Out:
#               carat      depth      table        price         x         y  \
# cut
# Fair       1.262045  64.057065  59.098702  4354.719702  6.243145  6.176154
# Good       0.965300  62.360744  58.709308  3947.706661  5.843970  5.856224
# Ideal      0.823890  61.709723  55.952511  3459.286371  5.508489  5.519776
# Premium    0.990755  61.263538  58.754905  4591.519724  5.970970  5.938764
# Very Geod  0.889305  61.814376  57.937967  4066.674731  5.761335  5.790390
# Very Good  0.887739  61.818946  57.960741  3963.478022  5.737255  5.766343
#
#                   z
# cut
# Fair       3.978693
# Good       3.644662
# Ideal      3.402974
# Premium    3.645592
# Very Geod  3.569775
# Very Good  3.558015

# %%
dia.pivot_table("carat",index = "cut",columns = "price")
# Out:
# price      326.0    335.0    336.0    337.0    338.0    339.0    340.0    \
# cut
# Fair           NaN      NaN      NaN     0.22      NaN      NaN      NaN
# Good           NaN     0.31      NaN      NaN      NaN      0.3      NaN
# Ideal         0.23      NaN      NaN      NaN      NaN      NaN     0.23
# Premium       0.21      NaN      NaN      NaN      NaN      NaN      NaN
# Very Geod      NaN      NaN      NaN      NaN     0.23      NaN      NaN
# Very Good      NaN      NaN     0.24     0.26      NaN      NaN      NaN
#
# price      342.0    344.0    345.0    ...  18787.0  18788.0  18791.0  18795.0  \
# cut                                   ...
# Fair           NaN      NaN      NaN  ...      NaN      NaN      NaN      NaN
# Good           NaN      NaN      NaN  ...      NaN      2.8      NaN      NaN
# Ideal          NaN     0.31      NaN  ...     2.05      NaN     2.15      NaN
# Premium       0.22      NaN     0.26  ...      NaN      NaN     1.71     2.02
# ...

# %%
carat = pd.cut(dia["carat"],[0.10,0.70,2.0])
carat.head(10)
# Out:
# 0    (0.7, 2.0]
# 1    (0.1, 0.7]
# 2    (0.7, 2.0]
# 3    (0.1, 0.7]
# 4           NaN
# 5    (0.1, 0.7]
# 6    (0.1, 0.7]
# 7    (0.1, 0.7]
# 8    (0.1, 0.7]
# 9    (0.1, 0.7]
# Name: carat, dtype: category
# Categories (2, interval[float64]): [(0.1, 0.7] < (0.7, 2.0]]

# %%
dia.pivot_table("price",["cut",carat])
# Out:
#                             price
# cut       carat
# Fair      (0.1, 0.7]  1446.650131
#           (0.7, 2.0]  4692.628192
# Good      (0.1, 0.7]  1169.496381
#           (0.7, 2.0]  5469.425453
# Ideal     (0.1, 0.7]  1200.295583
#           (0.7, 2.0]  6435.050506
# Premium   (0.1, 0.7]  1134.890037
#           (0.7, 2.0]  6333.057156
# Very Geod (0.1, 0.7]  1141.833822
#           (0.7, 2.0]  5928.618327
# Very Good (0.1, 0.7]  1141.993804
#           (0.7, 2.0]  5940.657770

# %%
dia2[dia2["cut"].isin(["Premium","Fair"])].head(10)
# Out:
#     carat      cut color clarity  depth  table    price     x     y     z
# 0    1.50     Fair     G     SI1   64.5   57.0  10352.0  7.15  7.09  4.59
# 2    1.22  Premium     G     VS1   61.3   58.0   8779.0  6.91  6.89  4.23
# 3    0.51  Premium     E     VS2   62.5   60.0   1590.0  5.08  5.10  3.18
# 7    0.55  Premium     F     SI2   60.6   58.0   1175.0  5.28  5.31  3.21
# 10   1.51  Premium     J     VS1   62.1   58.0   8524.0  7.40  7.36  4.58
# 12   1.05  Premium     D     SI1   61.6   61.0   5351.0  6.55  6.50  4.02
# 19   0.73  Premium     H     VS1   61.7   58.0   2468.0  5.75  5.72  3.54
# 21   1.01  Premium     D    VVS2   62.4   60.0  10407.0  6.36  6.31  3.95
# 22   1.00  Premium     F     VS2   62.7   58.0   6608.0  6.40  6.33  3.99
# 25   0.90     Fair     G     SI2   55.9   62.0   3104.0  6.35  6.42  3.57

# %%
import numpy as np
import pandas as pd
dia = pd.read_csv("DiamondData.csv")
dia.head(10)
# Out:
#    carat        cut color clarity  depth  table    price     x     y     z
# 0   1.50       Fair     G     SI1   64.5   57.0  10352.0  7.15  7.09  4.59
# 1   0.70      Ideal     E     VS2   61.4   57.0   2274.0  5.72  5.78  3.53
# 2   1.22    Premium     G     VS1   61.3   58.0   8779.0  6.91  6.89  4.23
# 3   0.51    Premium     E     VS2   62.5   60.0   1590.0  5.08  5.10  3.18
# 4   2.02  Very Good     J     SI2   59.2   60.0  11757.0  8.27  8.39  4.91
# 5   0.70  Very Good     E     SI1   63.2   61.0   2164.0  5.61  5.49  3.51
# 6   0.46      Ideal     G    VVS1   60.7   57.0   1453.0  4.98  5.03  3.04
# 7   0.55    Premium     F     SI2   60.6   58.0   1175.0  5.28  5.31  3.21
# 8   0.51      Ideal     G    VVS2   61.6   56.0   1750.0  5.12  5.14  3.16
# 9   0.50      Ideal     H     VS2   62.3   55.0   1921.0  5.09  5.12  3.18

# %%
dia.groupby("cut")[["carat","price"]].mean()
# Out:
#               carat        price
# cut
# Fair       1.262045  4354.719702
# Good       0.965300  3947.706661
# Ideal      0.823890  3459.286371
# Premium    0.990755  4591.519724
# Very Geod  0.889305  4066.674731
# Very Good  0.887739  3963.478022

# %%
carat = pd.cut(dia["carat"],[0.6,1.2,2])

# %%
dia.pivot_table("price",["cut",carat])
# Out:
#                              price
# cut       carat
# Fair      (0.6, 1.2]   3267.862656
#           (1.2, 2.0]   8022.376000
# Good      (0.6, 1.2]   3994.065030
#           (1.2, 2.0]   9180.934028
# Ideal     (0.6, 1.2]   4682.139987
#           (1.2, 2.0]  10011.437321
# Premium   (0.6, 1.2]   4388.174479
#           (1.2, 2.0]   9494.330450
# Very Geod (0.6, 1.2]   4264.972021
#           (1.2, 2.0]   9741.128378
# Very Good (0.6, 1.2]   4308.303459
#           (1.2, 2.0]   9725.945804

# %%
dia2 = dia.copy()

# %%
dia2[dia2["cut"].isin(["Premium","Fair","Very Good"])].head(10)
# Out:
#     carat        cut color clarity  depth  table    price     x     y     z
# 0    1.50       Fair     G     SI1   64.5   57.0  10352.0  7.15  7.09  4.59
# 2    1.22    Premium     G     VS1   61.3   58.0   8779.0  6.91  6.89  4.23
# 3    0.51    Premium     E     VS2   62.5   60.0   1590.0  5.08  5.10  3.18
# 4    2.02  Very Good     J     SI2   59.2   60.0  11757.0  8.27  8.39  4.91
# 5    0.70  Very Good     E     SI1   63.2   61.0   2164.0  5.61  5.49  3.51
# 7    0.55    Premium     F     SI2   60.6   58.0   1175.0  5.28  5.31  3.21
# 10   1.51    Premium     J     VS1   62.1   58.0   8524.0  7.40  7.36  4.58
# 12   1.05    Premium     D     SI1   61.6   61.0   5351.0  6.55  6.50  4.02
# 15   0.31  Very Good     H     SI1   61.1   57.0    446.0  4.32  4.35  2.65
# 18   0.71  Very Good     F    VVS2   62.0   56.0   3612.0  5.71  5.74  3.55

# %%
dia.groupby("color")[["carat","price"]].aggregate("mean")
# Out:
#           carat        price
# color
# D      0.735363  3179.130742
# E      0.777952  3089.462979
# F      0.889625  3727.827794
# G      0.855838  4004.067810
# H      1.001312  4474.284894
# I      1.165101  5102.384508
# J      1.255542  5337.071621

# %%
dia.pivot_table("price",["color","carat"]).head(10
# Out:
#                   price
# color carat
# D     0.20   367.000000
#       0.21   386.000000
#       0.22   404.000000
#       0.23   492.232558
#       0.24   510.111111
#       0.25   491.157895
#       0.26   551.363636
#       0.27   620.642857
#       0.28   605.214286
#       0.29   617.000000

# %%
import numpy as np
import pandas as pd
dia = pd.read_csv("DiamondData.csv")
dia.head(20)
# Out:
#     carat        cut color clarity  depth  table    price     x     y     z
# 0    1.50       Fair     G     SI1   64.5   57.0  10352.0  7.15  7.09  4.59
# 1    0.70      Ideal     E     VS2   61.4   57.0   2274.0  5.72  5.78  3.53
# 2    1.22    Premium     G     VS1   61.3   58.0   8779.0  6.91  6.89  4.23
# 3    0.51    Premium     E     VS2   62.5   60.0   1590.0  5.08  5.10  3.18
# 4    2.02  Very Good     J     SI2   59.2   60.0  11757.0  8.27  8.39  4.91
# 5    0.70  Very Good     E     SI1   63.2   61.0   2164.0  5.61  5.49  3.51
# 6    0.46      Ideal     G    VVS1   60.7   57.0   1453.0  4.98  5.03  3.04
# 7    0.55    Premium     F     SI2   60.6   58.0   1175.0  5.28  5.31  3.21
# 8    0.51      Ideal     G    VVS2   61.6   56.0   1750.0  5.12  5.14  3.16
# 9    0.50      Ideal     H     VS2   62.3   55.0   1921.0  5.09  5.12  3.18
# 10   1.51    Premium     J     VS1   62.1   58.0   8524.0  7.40  7.36  4.58
# ...

# %%
dia["carat"].max()
# Out:
# 49.9903589324094

# %%
dia["carat"].min()
# Out:
# 0.2

# %%
dia["carat"].mean()
# Out:
# 0.9069516025452978

# %%
dia.groupby("cut")[["carat","price"]].mean()
# Out:
#               carat        price
# cut
# Fair       1.262045  4354.719702
# Good       0.965300  3947.706661
# Ideal      0.823890  3459.286371
# Premium    0.990755  4591.519724
# Very Geod  0.889305  4066.674731
# Very Good  0.887739  3963.478022

# %%
carat = pd.cut(dia["carat"],[0.2,1,50])

# %%
dia.pivot_table("price",["cut",carat])
# Out:
#                              price
# cut       carat
# Fair      (0.2, 1.0]   2413.060920
#           (1.0, 50.0]  7137.657331
# Good      (0.2, 1.0]   2109.830220
#           (1.0, 50.0]  7728.799730
# Ideal     (0.2, 1.0]   1596.990031
#           (1.0, 50.0]  8607.164925
# Premium   (0.2, 1.0]   1813.638001
#           (1.0, 50.0]  8479.393166
# Very Geod (0.2, 1.0]   1899.916220
#           (1.0, 50.0]  8435.328378
# Very Good (0.2, 1.0]   1928.713082
#           (1.0, 50.0]  8264.618715

# %%
dia[dia["price"] == 18823.0]
# Out:
#        carat      cut color clarity  depth  table    price    x     y     z
# 21409   2.29  Premium     I     VS2   60.8   60.0  18823.0  8.5  8.47  5.16

# %%
dia["carat"].max()
# Out:
# 49.9903589324094

# %%
dia[dia["carat"] == 49.9903589324094]
# Out:
#            carat   cut color clarity  depth  table   price    x     y     z
# 17455  49.990359  Good     E     SI1   63.6   62.0  2407.0  5.6  5.57  3.55

# %%
dia.groupby("clarity")[["price","carat"]].mean()
# Out:
#                price     carat
# clarity
# I1       3860.487663  1.299561
# IF       2865.100845  0.591849
# SI1      4000.587245  0.930696
# SI2      5068.353945  1.200548
# VS1      3858.608390  0.844442
# VS2      3933.441153  0.886391
# VVS1     2551.304878  0.670633
# VVS2     3270.077616  0.689590
